# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Tools for Data Science

# %% [markdown]
# ## Introduction
# This notebook introduces some of the key tools used in Data Science and demonstrate simple arithmetic operations using python.

# %% [markdown]
# ## Data Science Languages
# Some of the commonly used languages in Data Science are:
#
# - Python
# - R
# - SQL
# - Scala
# - Julia

# %% [markdown]
# ## Data Science Libraries
# Popularlibraries used by data scientists include:
#
# - NumPy
# - Pandas
# - Matpotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool           | Description                      |
# |----------------|----------------------------------|
# | Jupyter        | Interactive coding environment   |
# | RStudio        | IDE for R                        |
# | Apache Spark   | Big data processing framework    |
# | TensorFlow     | Deep learning library            |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are examples of how to perform basic arithmetic operations such as addition and multiplication using Python.

# %%
# Multiply and Add Numbers 
(3 * 4) + 5
# Out:
# 17

# %%
# Convert Minutes to Hours 
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## List Objectives
# objectives
#
# - list data science languages
# - list data science libraries
# - Demonstrate simple arithmetic expressions
# - convert units usng python

# %% [markdown]
# # Author
# Kushaan Singh Jamwal
